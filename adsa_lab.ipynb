# %% [markdown]
# # Exp - 1 : Singly Linked List: Implement a singly linked list and perform basic operations like insertion, deletion, and traversal.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
class LinkedList:
    def __init__(self):
        self.head = None
    def insert_at_beginning(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node
    def insert_at_end(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            return
        current_node = self.head
        while current_node.next:
            current_node = current_node.next
        current_node.next = new_node
    def delete_from_beginning(self):
        if self.head:
            self.head = self.head.next
    def delete_at_position(self, position):
        if self.head is None:
            return
        if position == 1:
            self.head = self.head.next
            return
        current_node = self.head
        for _ in range(position - 2):
            if current_node.next is None:
                return
            current_node = current_node.next
        if current_node.next:
            current_node.next = current_node.next.next
    def display(self):
        current_node = self.head
        while current_node:
            print(current_node.data, end=" -> ")
            current_node = current_node.next
        print("None")
linked_list = LinkedList()
linked_list.insert_at_end(10)
linked_list.insert_at_end(20)
linked_list.insert_at_end(30)
linked_list.insert_at_end(40)
linked_list.insert_at_end(50)
print("Singly Linked List(Before Deletion): ", end="")
linked_list.display()
linked_list.delete_at_position(2)
print("Singly Linked List(After Deletion): ", end="")
linked_list.display()
# Out:
# Singly Linked List(Before Deletion): 10 -> 20 -> 30 -> 40 -> 50 -> None
# Singly Linked List(After Deletion): 10 -> 30 -> 40 -> 50 -> None

# %% [markdown]
# # Exp - 2 : Doubly Linked List: Implement a doubly linked list with operations like insertion, deletion, and traversal in both directions.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.prev = self.next = None
class DoublyLinkedList:
    def __init__(self):
        self.head = None
    def insert(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        current = self.head
        while current.next:
            current = current.next
        current.next = new_node
        new_node.prev = current
    def delete(self, position):
        if not self.head:
            return
        current = self.head
        if position == 1:
            self.head = current.next
            if self.head:
                self.head.prev = None
            return
        for _ in range(position - 1):
            if not current:
                return
            current = current.next
        if not current:
            return
        if current.prev:
            current.prev.next = current.next
        if current.next:
            current.next.prev = current.prev
    def display_forward(self):
        current = self.head
        while current:
            print(current.data, end=" <-> ")
            current = current.next
        print("None", "(Forward)")
    def display_backward(self):
        current = self.head
        while current and current.next:
            current = current.next
        while current:
            print(current.data, end=" <-> ")
            current = current.prev
        print("None", "(Backward)")
dll = DoublyLinkedList()
dll.insert(10)
dll.insert(20)
dll.insert(30)
print("Doubly Linked List(Before Deletion): ")
dll.display_forward()
dll.display_backward()
dll.delete(2)
print("\nDoubly Linked List(After Deletion): ")
dll.display_forward()
dll.display_backward()
# Out:
# Doubly Linked List(Before Deletion):
# 10 <-> 20 <-> 30 <-> None (Forward)
# 30 <-> 20 <-> 10 <-> None (Backward)
#
# Doubly Linked List(After Deletion):
# 10 <-> 30 <-> None (Forward)
# 30 <-> 10 <-> None (Backward)

# %% [markdown]
# # Exp - 3 : Stack Implementation: Implement a stack using arrays or linked lists, and perform operations such as push, pop, and peek.

# %%
class Stack:
    def __init__(self):
        self.stack = []
    def push(self, value):
        self.stack.append(value)
    def pop(self):
        if self.stack:
            return self.stack.pop()
    def peek(self):
        if self.stack:
            return self.stack[-1]
    def display(self):
        print(self.stack[::-1])
stack = Stack()
stack.push(10)
stack.push(20)
stack.push(30)
print("Stack: ", end="")
stack.display()
print("Popped:", stack.pop())
print("Top:", stack.peek())
print("Stack after pop: ", end="")
stack.display()
# Out:
# Stack: [30, 20, 10]
# Popped: 30
# Top: 20
# Stack after pop: [20, 10]

# %% [markdown]
# # Exp - 4 : Queue Implementation: Implement a queue using arrays or linked lists with operations such as enqueue, dequeue, and peek.

# %%
class Queue:
    def __init__(self):
        self.queue = []
    def enqueue(self, value):
        self.queue.append(value)
    def dequeue(self):
        if self.queue:
            return self.queue.pop(0)
    def peek(self):
        if self.queue:
            return self.queue[0]
    def display(self):
        print(self.queue)
queue = Queue()
queue.enqueue(10)
queue.enqueue(20)
queue.enqueue(30)
print("Queue: ", end="")
queue.display()
print("Removed:", queue.dequeue())
print("Front:", queue.peek())
print("Queue after dequeue: ", end="")
queue.display()
# Out:
# Queue: [10, 20, 30]
# Removed: 10
# Front: 20
# Queue after dequeue: [20, 30]

# %% [markdown]
# # Exp - 5 : Binary Search Tree (BST): Implement a Binary Search Tree with insert, delete, search, and traversal methods (pre-order, in-order, and post-order).

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.left = self.right = None
class BST:
    def insert(self, root, value):
        if root is None:
            return Node(value)
        if value < root.value:
            root.left = self.insert(root.left, value)
        else:
            root.right = self.insert(root.right, value)
        return root
    def search(self, root, value):
        if root is None:
            return False
        if root.value == value:
            return True
        if value < root.value:
            return self.search(root.left, value)
        return self.search(root.right, value)
    def delete(self, root, value):
        if root is None:
            return None
        if value < root.value:
            root.left = self.delete(root.left, value)
        elif value > root.value:
            root.right = self.delete(root.right, value)
        else:
            if root.left is None:
                return root.right
            if root.right is None:
                return root.left
            temp = root.right
            while temp.left:
                temp = temp.left
            root.value = temp.value
            root.right = self.delete(root.right, temp.value)
        return root
    def inorder(self, root):
        if root:
            self.inorder(root.left)
            print(root.value, end=" ")
            self.inorder(root.right)
    def preorder(self, root):
        if root:
            print(root.value, end=" ")
            self.preorder(root.left)
            self.preorder(root.right)
    def postorder(self, root):
        if root:
            self.postorder(root.left)
            self.postorder(root.right)
            print(root.value, end=" ")
tree = BST()
root = None
for value in [50, 30, 70, 20, 40, 60, 80]:
    root = tree.insert(root, value)
    root = tree.delete(root, 30)
print("Inorder: ")
tree.inorder(root)
print("\nPreorder: ")
tree.preorder(root)
print("\nPostorder: ")
tree.postorder(root)
# Out:
# Inorder:
# 20 40 50 60 70 80
# Preorder:
# 50 20 40 70 60 80
# Postorder:
# 40 20 60 80 70 50

# %% [markdown]
# # Exp - 6 : AVL Tree Implementation: Implement an AVL Tree with self-balancing functionality using rotations (left and right) to maintain balance.

# %%
class Node:
    def __init__(self, key):
        self.key = key
        self.left = self.right = None
        self.height = 1
class AVLTree:
    def height(self, node):
        return node.height if node else 0
    def balance(self, node):
        return self.height(node.left) - self.height(node.right) if node else 0
    def right_rotate(self, y):
        print("\nBefore Right Rotation:", y.key)
        x = y.left
        y.left = x.right
        x.right = y
        y.height = 1 + max(self.height(y.left), self.height(y.right))
        x.height = 1 + max(self.height(x.left), self.height(x.right))
        print("After Right Rotation:", x.key)
        return x
    def left_rotate(self, x):
        print("\nBefore Left Rotation:", x.key)
        y = x.right
        x.right = y.left
        y.left = x
        x.height = 1 + max(self.height(x.left), self.height(x.right))
        y.height = 1 + max(self.height(y.left), self.height(y.right))
        print("After Left Rotation:", y.key)
        return y
    def insert(self, root, key):
        if not root:
            return Node(key)
        if key < root.key:
            root.left = self.insert(root.left, key)
        else:
            root.right = self.insert(root.right, key)
        root.height = 1 + max(self.height(root.left), self.height(root.right))
        balance = self.balance(root)
        if balance > 1 and key < root.left.key:
            return self.right_rotate(root)
        if balance < -1 and key > root.right.key:
            return self.left_rotate(root)
        if balance > 1 and key > root.left.key:
            root.left = self.left_rotate(root.left)
            return self.right_rotate(root)
        if balance < -1 and key < root.right.key:
            root.right = self.right_rotate(root.right)
            return self.left_rotate(root)
        return root
tree = AVLTree()
root = None
for value in [10, 20, 30, 40, 50, 25]:
    print("\nInserting:", value)
    root = tree.insert(root, value)
# Out:
# Inserting: 10
#
# Inserting: 20
#
# Inserting: 30
#
# Before Left Rotation: 10
# After Left Rotation: 20
#
# Inserting: 40
#
# Inserting: 50
#
# Before Left Rotation: 30
# After Left Rotation: 40
#
# Inserting: 25
#
# Before Right Rotation: 40
# After Right Rotation: 30
#
# Before Left Rotation: 20
# After Left Rotation: 30

# %% [markdown]
# # Exp - 7 : B-Tree Implementation: Implement a B-tree with insertion, deletion, and balancing operations to handle large-scale data efficiently.

# %%
class Node:
    def __init__(self, t, leaf=False):
        self.t, self.leaf = t, leaf
        self.keys, self.children = [], []
class BTree:
    def __init__(self, t):
        self.root = Node(t, True)
        self.t = t
    def traverse(self, node):
        for i in range(len(node.keys)):
            if not node.leaf:
                self.traverse(node.children[i])
            print(node.keys[i], end=" ")
        if not node.leaf:
            self.traverse(node.children[len(node.keys)])
    def insert(self, key):
        r = self.root
        if len(r.keys) == 2*self.t - 1:
            new = Node(self.t)
            new.children.append(r)
            self.split(new, 0)
            self.root = new
        self.insert_non_full(self.root, key)
    def insert_non_full(self, node, key):
        i = len(node.keys) - 1
        if node.leaf:
            node.keys.append(0)
            while i >= 0 and key < node.keys[i]:
                node.keys[i+1] = node.keys[i]
                i -= 1
            node.keys[i+1] = key
        else:
            while i >= 0 and key < node.keys[i]:
                i -= 1
            i += 1
            if len(node.children[i].keys) == 2*self.t - 1:
                self.split(node, i)
                if key > node.keys[i]:
                    i += 1
            self.insert_non_full(node.children[i], key)
    def split(self, parent, i):
        t = self.t
        y = parent.children[i]
        z = Node(t, y.leaf)
        parent.children.insert(i+1, z)
        parent.keys.insert(i, y.keys[t-1])
        z.keys, y.keys = y.keys[t:], y.keys[:t-1]
        if not y.leaf:
            z.children, y.children = y.children[t:], y.children[:t]
    def delete(self, node, key):
        t, i = self.t, 0
        while i < len(node.keys) and key > node.keys[i]:
            i += 1
        if i < len(node.keys) and node.keys[i] == key:
            if node.leaf:
                node.keys.pop(i)
            else:
                if len(node.children[i].keys) >= t:
                    pred = self.get_pred(node, i)
                    node.keys[i] = pred
                    self.delete(node.children[i], pred)
                elif len(node.children[i+1].keys) >= t:
                    succ = self.get_succ(node, i)
                    node.keys[i] = succ
                    self.delete(node.children[i+1], succ)
                else:
                    self.merge(node, i)
                    self.delete(node.children[i], key)
        else:
            if node.leaf:
                return
            if len(node.children[i].keys) < t:
                self.fill(node, i)
            self.delete(node.children[i], key)
    def get_pred(self, node, i):
        cur = node.children[i]
        while not cur.leaf:
            cur = cur.children[-1]
        return cur.keys[-1]
    def get_succ(self, node, i):
        cur = node.children[i+1]
        while not cur.leaf:
            cur = cur.children[0]
        return cur.keys[0]
    def fill(self, node, i):
        if i > 0 and len(node.children[i-1].keys) >= self.t:
            self.borrow_prev(node, i)
        elif i < len(node.keys) and len(node.children[i+1].keys) >= self.t:
            self.borrow_next(node, i)
        else:
            self.merge(node, i if i < len(node.keys) else i-1)
    def borrow_prev(self, node, i):
        child, sib = node.children[i], node.children[i-1]
        child.keys.insert(0, node.keys[i-1])
        if not child.leaf:
            child.children.insert(0, sib.children.pop())
        node.keys[i-1] = sib.keys.pop()
    def borrow_next(self, node, i):
        child, sib = node.children[i], node.children[i+1]
        child.keys.append(node.keys[i])
        if not child.leaf:
            child.children.append(sib.children.pop(0))
        node.keys[i] = sib.keys.pop(0)
    def merge(self, node, i):
        c, s = node.children[i], node.children[i+1]
        c.keys += [node.keys[i]] + s.keys
        if not c.leaf:
            c.children += s.children
        node.keys.pop(i)
        node.children.pop(i+1)
bt = BTree(3)
for v in [10, 20, 5, 6, 12, 30, 7, 17]:
    bt.insert(v)
print("B-Tree before deletion:")
bt.traverse(bt.root)
bt.delete(bt.root, 6)
print("\nB-Tree After deletion:")
bt.traverse(bt.root)
# Out:
# B-Tree before deletion:
# 5 6 7 10 12 17 20 30
# B-Tree After deletion:
# 5 7 10 12 17 20 30
